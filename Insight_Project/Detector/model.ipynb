# %%
from Web_Attack_Predictor import *
# Out:
#                                payload  is_malicious injection_type
# index
# 0                            37662577P           0.0          LEGAL
# 1                             shirting           0.0          LEGAL
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS
# 3                              obeying           0.0          LEGAL
# 4                            dictating           0.0          LEGAL
# 5                              lafleur           0.0          LEGAL
# 6                            capturers           0.0          LEGAL
# 7                            8nca58z48           0.0          LEGAL
# 8                           autocratic           0.0          LEGAL
# 9                   grocery+warehouses           0.0          LEGAL
# 10                             Danciel           0.0          LEGAL
# 11                             Koressa           0.0          LEGAL
# 12         bowie0%40showeb-handling.bi           0.0          LEGAL
# 13                          Auque+Cote           0.0          LEGAL
# 14                            broadest           0.0          LEGAL
# 15                      Xaubet+Sorolla           0.0          LEGAL
# 16                          vocational           0.0          LEGAL
# 17                               Yemen           0.0          LEGAL
# 18                               22584           0.0          LEGAL
# 19             <BR SIZE="&{alert(1)}">           1.0            XSS
# <class 'pandas.core.frame.DataFrame'> (110357, 3)
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# 37                                                 outdo           0.0
# 38                                       Guadiana+149+6F           0.0
# 39                                                  3110           0.0
# 40                                           geophysical           0.0
# 41                              ../../../../etc/hosts/.'           1.0
# 42     http%3A%2F%2Fwww.naturalnews.com%2F027434_cila...           0.0
# 43                                                  Yaco           0.0
# 44                                       Rapetto+Picabea           0.0
# 45                                              tomahawk           0.0
# 46                                                 31790           0.0
# 47                                                 47182           0.0
# 48                                          Derch+Mallol           0.0
# 49                                                Russel           0.0
#
#       injection_type
# index
# 0              LEGAL
# 1              LEGAL
# 2                XSS
# 3              LEGAL
# 4              LEGAL
# 5              LEGAL
# 6              LEGAL
# 7              LEGAL
# 8              LEGAL
# 9              LEGAL
# 10             LEGAL
# 11             LEGAL
# 12             LEGAL
# 13             LEGAL
# 14             LEGAL
# 15             LEGAL
# 16             LEGAL
# 17             LEGAL
# 18             LEGAL
# 19               XSS
# 20             LEGAL
# 21               XSS
# 22               XSS
# 23             LEGAL
# 24             LEGAL
# 25             LEGAL
# 26             LEGAL
# 27             LEGAL
# 28             LEGAL
# 29             LEGAL
# 30             LEGAL
# 31             LEGAL
# 32             LEGAL
# 33             LEGAL
# 34             LEGAL
# 35             LEGAL
# 36             LEGAL
# 37             LEGAL
# 38             LEGAL
# 39             LEGAL
# 40             LEGAL
# 41             SHELL
# 42             LEGAL
# 43             LEGAL
# 44             LEGAL
# 45             LEGAL
# 46             LEGAL
# 47             LEGAL
# 48             LEGAL
# 49             LEGAL
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# 37                                                 outdo           0.0
# 38                                       Guadiana+149+6F           0.0
# 39                                                  3110           0.0
# 40                                           geophysical           0.0
# 41                              ../../../../etc/hosts/.'           1.0
# 42     http%3A%2F%2Fwww.naturalnews.com%2F027434_cila...           0.0
# 43                                                  Yaco           0.0
# 44                                       Rapetto+Picabea           0.0
# 45                                              tomahawk           0.0
# 46                                                 31790           0.0
# 47                                                 47182           0.0
# 48                                          Derch+Mallol           0.0
# 49                                                Russel           0.0
#
#       injection_type  length
# index
# 0              LEGAL       9
# 1              LEGAL       8
# 2                XSS      31
# 3              LEGAL       7
# 4              LEGAL       9
# 5              LEGAL       7
# 6              LEGAL       9
# 7              LEGAL       9
# 8              LEGAL      10
# 9              LEGAL      18
# 10             LEGAL       7
# 11             LEGAL       7
# 12             LEGAL      27
# 13             LEGAL      10
# 14             LEGAL       8
# 15             LEGAL      14
# 16             LEGAL      10
# 17             LEGAL       5
# 18             LEGAL       5
# 19               XSS      23
# 20             LEGAL       9
# 21               XSS      67
# 22               XSS      50
# 23             LEGAL       5
# 24             LEGAL       9
# 25             LEGAL      14
# 26             LEGAL       8
# 27             LEGAL       7
# 28             LEGAL       8
# 29             LEGAL       6
# 30             LEGAL       6
# 31             LEGAL      16
# 32             LEGAL      20
# 33             LEGAL      12
# 34             LEGAL      28
# 35             LEGAL       5
# 36             LEGAL      10
# 37             LEGAL       5
# 38             LEGAL      15
# 39             LEGAL       4
# 40             LEGAL      11
# 41             SHELL      24
# 42             LEGAL      68
# 43             LEGAL       4
# 44             LEGAL      15
# 45             LEGAL       8
# 46             LEGAL       5
# 47             LEGAL       5
# 48             LEGAL      12
# 49             LEGAL       6
# length
# count    110357.000000
# mean         16.559629
# std          32.108640
# min           1.000000
# 25%           6.000000
# 50%           9.000000
# 75%          14.000000
# max         974.000000
# Name: length, dtype: float64
# length
# float64
# <bound method Series.mean of count    110357.000000
# mean         16.559629
# std          32.108640
# min           1.000000
# 25%           6.000000
# 50%           9.000000
# 75%          14.000000
# max         974.000000
# Name: length, dtype: float64>
# 974.0
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#  100 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# 37                                                 outdo           0.0
# 38                                       Guadiana+149+6F           0.0
# 39                                                  3110           0.0
# 40                                           geophysical           0.0
# 41                              ../../../../etc/hosts/.'           1.0
# 42     http%3A%2F%2Fwww.naturalnews.com%2F027434_cila...           0.0
# 43                                                  Yaco           0.0
# 44                                       Rapetto+Picabea           0.0
# 45                                              tomahawk           0.0
# 46                                                 31790           0.0
# 47                                                 47182           0.0
# 48                                          Derch+Mallol           0.0
# 49                                                Russel           0.0
#
#       injection_type  length  non_printable_chars
# index
# 0              LEGAL       9                    0
# 1              LEGAL       8                    0
# 2                XSS      31                    0
# 3              LEGAL       7                    0
# 4              LEGAL       9                    0
# 5              LEGAL       7                    0
# 6              LEGAL       9                    0
# 7              LEGAL       9                    0
# 8              LEGAL      10                    0
# 9              LEGAL      18                    0
# 10             LEGAL       7                    0
# 11             LEGAL       7                    0
# 12             LEGAL      27                    0
# 13             LEGAL      10                    0
# 14             LEGAL       8                    0
# 15             LEGAL      14                    0
# 16             LEGAL      10                    0
# 17             LEGAL       5                    0
# 18             LEGAL       5                    0
# 19               XSS      23                    0
# 20             LEGAL       9                    0
# 21               XSS      67                    0
# 22               XSS      50                    0
# 23             LEGAL       5                    0
# 24             LEGAL       9                    0
# 25             LEGAL      14                    0
# 26             LEGAL       8                    0
# 27             LEGAL       7                    0
# 28             LEGAL       8                    0
# 29             LEGAL       6                    0
# 30             LEGAL       6                    0
# 31             LEGAL      16                    0
# 32             LEGAL      20                    0
# 33             LEGAL      12                    0
# 34             LEGAL      28                    0
# 35             LEGAL       5                    0
# 36             LEGAL      10                    0
# 37             LEGAL       5                    0
# 38             LEGAL      15                    0
# 39             LEGAL       4                    0
# 40             LEGAL      11                    0
# 41             SHELL      24                    0
# 42             LEGAL      68                    0
# 43             LEGAL       4                    0
# 44             LEGAL      15                    0
# 45             LEGAL       8                    0
# 46             LEGAL       5                    0
# 47             LEGAL       5                    0
# 48             LEGAL      12                    0
# 49             LEGAL       6                    0
# non_printable_chars
# count    110357.000000
# mean          0.007412
# std           0.216736
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          30.000000
# Name: non_printable_chars, dtype: float64
# non_printable_chars
# float64
# <bound method Series.mean of count    110357.000000
# mean          0.007412
# std           0.216736
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          30.000000
# Name: non_printable_chars, dtype: float64>
# 30.0
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# 37                                                 outdo           0.0
# 38                                       Guadiana+149+6F           0.0
# 39                                                  3110           0.0
# 40                                           geophysical           0.0
# 41                              ../../../../etc/hosts/.'           1.0
# 42     http%3A%2F%2Fwww.naturalnews.com%2F027434_cila...           0.0
# 43                                                  Yaco           0.0
# 44                                       Rapetto+Picabea           0.0
# 45                                              tomahawk           0.0
# 46                                                 31790           0.0
# 47                                                 47182           0.0
# 48                                          Derch+Mallol           0.0
# 49                                                Russel           0.0
#
#       injection_type  length  non_printable_chars  punctuation
# index
# 0              LEGAL       9                    0            0
# 1              LEGAL       8                    0            0
# 2                XSS      31                    0           11
# 3              LEGAL       7                    0            0
# 4              LEGAL       9                    0            0
# 5              LEGAL       7                    0            0
# 6              LEGAL       9                    0            0
# 7              LEGAL       9                    0            0
# 8              LEGAL      10                    0            0
# 9              LEGAL      18                    0            1
# 10             LEGAL       7                    0            0
# 11             LEGAL       7                    0            0
# 12             LEGAL      27                    0            3
# 13             LEGAL      10                    0            1
# 14             LEGAL       8                    0            0
# 15             LEGAL      14                    0            1
# 16             LEGAL      10                    0            0
# 17             LEGAL       5                    0            0
# 18             LEGAL       5                    0            0
# 19               XSS      23                    0           10
# 20             LEGAL       9                    0            0
# 21               XSS      67                    0           18
# 22               XSS      50                    0           16
# 23             LEGAL       5                    0            0
# 24             LEGAL       9                    0            0
# 25             LEGAL      14                    0            4
# 26             LEGAL       8                    0            0
# 27             LEGAL       7                    0            0
# 28             LEGAL       8                    0            0
# 29             LEGAL       6                    0            0
# 30             LEGAL       6                    0            0
# 31             LEGAL      16                    0            0
# 32             LEGAL      20                    0            3
# 33             LEGAL      12                    0            0
# 34             LEGAL      28                    0            3
# 35             LEGAL       5                    0            0
# 36             LEGAL      10                    0            0
# 37             LEGAL       5                    0            0
# 38             LEGAL      15                    0            2
# 39             LEGAL       4                    0            0
# 40             LEGAL      11                    0            0
# 41             SHELL      24                    0           16
# 42             LEGAL      68                    0           10
# 43             LEGAL       4                    0            0
# 44             LEGAL      15                    0            1
# 45             LEGAL       8                    0            0
# 46             LEGAL       5                    0            0
# 47             LEGAL       5                    0            0
# 48             LEGAL      12                    0            1
# 49             LEGAL       6                    0            0
# punctuation
# count    110357.000000
# mean          2.363729
# std           9.771260
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         538.000000
# Name: punctuation, dtype: float64
# punctuation
# float64
# <bound method Series.mean of count    110357.000000
# mean          2.363729
# std           9.771260
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         538.000000
# Name: punctuation, dtype: float64>
# 538.0
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# 37                                                 outdo           0.0
# 38                                       Guadiana+149+6F           0.0
# 39                                                  3110           0.0
# 40                                           geophysical           0.0
# 41                              ../../../../etc/hosts/.'           1.0
# 42     http%3A%2F%2Fwww.naturalnews.com%2F027434_cila...           0.0
# 43                                                  Yaco           0.0
# 44                                       Rapetto+Picabea           0.0
# 45                                              tomahawk           0.0
# 46                                                 31790           0.0
# 47                                                 47182           0.0
# 48                                          Derch+Mallol           0.0
# 49                                                Russel           0.0
#
#       injection_type  length  non_printable_chars  punctuation  min-byte
# index
# 0              LEGAL       9                    0            0        50
# 1              LEGAL       8                    0            0       103
# 2                XSS      31                    0           11        37
# 3              LEGAL       7                    0            0        98
# 4              LEGAL       9                    0            0        97
# 5              LEGAL       7                    0            0        97
# 6              LEGAL       9                    0            0        97
# 7              LEGAL       9                    0            0        52
# 8              LEGAL      10                    0            0        97
# 9              LEGAL      18                    0            1        43
# 10             LEGAL       7                    0            0        68
# 11             LEGAL       7                    0            0        75
# 12             LEGAL      27                    0            3        37
# 13             LEGAL      10                    0            1        43
# 14             LEGAL       8                    0            0        97
# 15             LEGAL      14                    0            1        43
# 16             LEGAL      10                    0            0        97
# 17             LEGAL       5                    0            0        89
# 18             LEGAL       5                    0            0        50
# 19               XSS      23                    0           10        32
# 20             LEGAL       9                    0            0        97
# 21               XSS      67                    0           18        32
# 22               XSS      50                    0           16        32
# 23             LEGAL       5                    0            0        48
# 24             LEGAL       9                    0            0        97
# 25             LEGAL      14                    0            4        37
# 26             LEGAL       8                    0            0        80
# 27             LEGAL       7                    0            0        65
# 28             LEGAL       8                    0            0        66
# 29             LEGAL       6                    0            0       100
# 30             LEGAL       6                    0            0        65
# 31             LEGAL      16                    0            0        48
# 32             LEGAL      20                    0            3        37
# 33             LEGAL      12                    0            0        97
# 34             LEGAL      28                    0            3        37
# 35             LEGAL       5                    0            0        49
# 36             LEGAL      10                    0            0        97
# 37             LEGAL       5                    0            0       100
# 38             LEGAL      15                    0            2        43
# 39             LEGAL       4                    0            0        48
# 40             LEGAL      11                    0            0        97
# 41             SHELL      24                    0           16        39
# 42             LEGAL      68                    0           10        37
# 43             LEGAL       4                    0            0        89
# 44             LEGAL      15                    0            1        43
# 45             LEGAL       8                    0            0        97
# 46             LEGAL       5                    0            0        48
# 47             LEGAL       5                    0            0        49
# 48             LEGAL      12                    0            1        43
# 49             LEGAL       6                    0            0        82
# min-byte
# count    110357.000000
# mean         71.225749
# std          26.545783
# min           9.000000
# 25%          48.000000
# 50%          75.000000
# 75%          97.000000
# max         125.000000
# Name: min-byte, dtype: float64
# min-byte
# float64
# <bound method Series.mean of count    110357.000000
# mean         71.225749
# std          26.545783
# min           9.000000
# 25%          48.000000
# 50%          75.000000
# 75%          97.000000
# max         125.000000
# Name: min-byte, dtype: float64>
# 125.0
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# 37                                                 outdo           0.0
# 38                                       Guadiana+149+6F           0.0
# 39                                                  3110           0.0
# 40                                           geophysical           0.0
# 41                              ../../../../etc/hosts/.'           1.0
# 42     http%3A%2F%2Fwww.naturalnews.com%2F027434_cila...           0.0
# 43                                                  Yaco           0.0
# 44                                       Rapetto+Picabea           0.0
# 45                                              tomahawk           0.0
# 46                                                 31790           0.0
# 47                                                 47182           0.0
# 48                                          Derch+Mallol           0.0
# 49                                                Russel           0.0
#
#       injection_type  length  non_printable_chars  punctuation  min-byte  \
# index
# 0              LEGAL       9                    0            0        50
# 1              LEGAL       8                    0            0       103
# 2                XSS      31                    0           11        37
# 3              LEGAL       7                    0            0        98
# 4              LEGAL       9                    0            0        97
# 5              LEGAL       7                    0            0        97
# 6              LEGAL       9                    0            0        97
# 7              LEGAL       9                    0            0        52
# 8              LEGAL      10                    0            0        97
# 9              LEGAL      18                    0            1        43
# 10             LEGAL       7                    0            0        68
# 11             LEGAL       7                    0            0        75
# 12             LEGAL      27                    0            3        37
# 13             LEGAL      10                    0            1        43
# 14             LEGAL       8                    0            0        97
# 15             LEGAL      14                    0            1        43
# 16             LEGAL      10                    0            0        97
# 17             LEGAL       5                    0            0        89
# 18             LEGAL       5                    0            0        50
# 19               XSS      23                    0           10        32
# 20             LEGAL       9                    0            0        97
# 21               XSS      67                    0           18        32
# 22               XSS      50                    0           16        32
# 23             LEGAL       5                    0            0        48
# 24             LEGAL       9                    0            0        97
# 25             LEGAL      14                    0            4        37
# 26             LEGAL       8                    0            0        80
# 27             LEGAL       7                    0            0        65
# 28             LEGAL       8                    0            0        66
# 29             LEGAL       6                    0            0       100
# 30             LEGAL       6                    0            0        65
# 31             LEGAL      16                    0            0        48
# 32             LEGAL      20                    0            3        37
# 33             LEGAL      12                    0            0        97
# 34             LEGAL      28                    0            3        37
# 35             LEGAL       5                    0            0        49
# 36             LEGAL      10                    0            0        97
# 37             LEGAL       5                    0            0       100
# 38             LEGAL      15                    0            2        43
# 39             LEGAL       4                    0            0        48
# 40             LEGAL      11                    0            0        97
# 41             SHELL      24                    0           16        39
# 42             LEGAL      68                    0           10        37
# 43             LEGAL       4                    0            0        89
# 44             LEGAL      15                    0            1        43
# 45             LEGAL       8                    0            0        97
# 46             LEGAL       5                    0            0        48
# 47             LEGAL       5                    0            0        49
# 48             LEGAL      12                    0            1        43
# 49             LEGAL       6                    0            0        82
#
#        max-byte
# index
# 0            80
# 1           116
# 2           119
# 3           121
# 4           116
# 5           117
# 6           117
# 7           122
# 8           117
# 9           121
# 10          110
# 11          115
# 12          119
# 13          117
# 14          116
# 15          117
# 16          118
# 17          110
# 18           56
# 19          125
# 20          116
# 21          120
# 22          118
# 23           56
# 24          112
# 25          114
# 26          116
# 27          114
# 28          119
# 29          116
# 30          115
# 31           56
# 32          118
# 33          121
# 34          115
# 35           55
# 36          116
# 37          117
# 38          117
# 39           51
# 40          121
# 41          116
# 42          120
# 43          111
# 44          116
# 45          119
# 46           57
# 47           56
# 48          114
# 49          117
# max-byte
# count    110357.000000
# mean        109.495166
# std          20.327684
# min          33.000000
# 25%         114.000000
# 50%         116.000000
# 75%         118.000000
# max         240.000000
# Name: max-byte, dtype: float64
# max-byte
# float64
# <bound method Series.mean of count    110357.000000
# mean        109.495166
# std          20.327684
# min          33.000000
# 25%         114.000000
# 50%         116.000000
# 75%         118.000000
# max         240.000000
# Name: max-byte, dtype: float64>
# 240.0
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
# 30                                                Alissa           0.0
# 31                                      1027246428586184           0.0
# 32                                  Condado+de+Trevi%F1o           0.0
# 33                                          imperatively           0.0
# 34                          hindman%40primeracasa-ebs.il           0.0
# 35                                                 42127           0.0
# 36                                            reparation           0.0
# ...
#   FutureWarning)
# (27590,)
# [[25047    63]
#  [  372  2108]]
# 25047 63 372 2108
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99     25110
#          1.0       0.97      0.85      0.91      2480
#
#    micro avg       0.98      0.98      0.98     27590
#    macro avg       0.98      0.92      0.95     27590
# weighted avg       0.98      0.98      0.98     27590
#
# hamming loss:  0.015766582094961942
# log loss:  0.5445602793194734
# zero one loss:  0.015766582094961956
# mean absolute error:  0.015766582094961942
# mean squared error:  0.015766582094961942
# mean squared log error:  0.007575101886713214
# median absolute error:  0.0
# accuracy score:  0.984233417905038
# precision score:  0.9709811146936895
# recall score:  0.85
# F1 score:  0.9064717265104278
# auc_score:  0.9237455197132617
# precision_recall_curve:
#  (array([0.08988764, 0.97098111, 1.        ]), array([1.  , 0.85, 0.  ]), array([0., 1.]))
# [0.08988764 0.97098111 1.        ] [1.   0.85 0.  ] [0. 1.]
# roc curve:
#  (array([0.        , 0.00250896, 1.        ]), array([0.  , 0.85, 1.  ]), array([2., 1., 0.]))
# [0.         0.00250896 1.        ] [0.   0.85 1.  ] [2. 1. 0.]
# /Users/user/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# (27590,)
# [[25042    68]
#  [  400  2080]]
# 25042 68 400 2080
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99     25110
#          1.0       0.97      0.84      0.90      2480
#
#    micro avg       0.98      0.98      0.98     27590
#    macro avg       0.98      0.92      0.94     27590
# weighted avg       0.98      0.98      0.98     27590
#
# hamming loss:  0.016962667633200434
# log loss:  0.5858717551809887
# zero one loss:  0.016962667633200423
# mean absolute error:  0.016962667633200434
# mean squared error:  0.016962667633200434
# mean squared log error:  0.008149764788463873
# median absolute error:  0.0
# accuracy score:  0.9830373323667996
# precision score:  0.9683426443202979
# recall score:  0.8387096774193549
# F1 score:  0.898876404494382
# auc_score:  0.9180007964954202
# precision_recall_curve:
#  (array([0.08988764, 0.96834264, 1.        ]), array([1.        , 0.83870968, 0.        ]), array([0., 1.]))
# [0.08988764 0.96834264 1.        ] [1.         0.83870968 0.        ] [0. 1.]
# roc curve:
#  (array([0.        , 0.00270808, 1.        ]), array([0.        , 0.83870968, 1.        ]), array([2., 1., 0.]))
# [0.         0.00270808 1.        ] [0.         0.83870968 1.        ] [2. 1. 0.]
# /Users/user/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# (27590,)
# [[25108     2]
#  [ 1302  1178]]
# 25108 2 1302 1178
#               precision    recall  f1-score   support
#
#          0.0       0.95      1.00      0.97     25110
#          1.0       1.00      0.47      0.64      2480
#
#    micro avg       0.95      0.95      0.95     27590
#    macro avg       0.97      0.74      0.81     27590
# weighted avg       0.95      0.95      0.94     27590
#
# hamming loss:  0.04726350126857557
# log loss:  1.6324235599187535
# zero one loss:  0.04726350126857559
# mean absolute error:  0.04726350126857557
# mean squared error:  0.04726350126857557
# mean squared log error:  0.022707891632813865
# median absolute error:  0.0
# accuracy score:  0.9527364987314244
# precision score:  0.9983050847457627
# recall score:  0.475
# F1 score:  0.6437158469945355
# auc_score:  0.7374601752289924
# precision_recall_curve:
#  (array([0.08988764, 0.99830508, 1.        ]), array([1.   , 0.475, 0.   ]), array([0., 1.]))
# [0.08988764 0.99830508 1.        ] [1.    0.475 0.   ] [0. 1.]
# roc curve:
#  (array([0.0000000e+00, 7.9649542e-05, 1.0000000e+00]), array([0.   , 0.475, 1.   ]), array([2., 1., 0.]))
# [0.0000000e+00 7.9649542e-05 1.0000000e+00] [0.    0.475 1.   ] [2. 1. 0.]
# Iteration 1, loss = 0.09198952
# Iteration 2, loss = 0.05854882
# Iteration 3, loss = 0.05313172
# Iteration 4, loss = 0.04681886
# Iteration 5, loss = 0.04421632
# Iteration 6, loss = 0.03967832
# Iteration 7, loss = 0.04080038
# Iteration 8, loss = 0.03718321
# Iteration 9, loss = 0.03740369
# Iteration 10, loss = 0.03631718
# Iteration 11, loss = 0.03595444
# Iteration 12, loss = 0.03582617
# Iteration 13, loss = 0.03417295
# Iteration 14, loss = 0.03456803
# Iteration 15, loss = 0.03495145
# Iteration 16, loss = 0.03391354
# Iteration 17, loss = 0.03295376
# Iteration 18, loss = 0.03413813
# Iteration 19, loss = 0.03222345
# Iteration 20, loss = 0.03302716
# Iteration 21, loss = 0.03338554
# Iteration 22, loss = 0.03294630
# Iteration 23, loss = 0.03180160
# Iteration 24, loss = 0.03417714
# Iteration 25, loss = 0.03330814
# Iteration 26, loss = 0.03190396
# Iteration 27, loss = 0.03214465
# Iteration 28, loss = 0.03275711
# Iteration 29, loss = 0.03171695
# Iteration 30, loss = 0.03347272
# Iteration 31, loss = 0.03102030
# Iteration 32, loss = 0.03198163
# Iteration 33, loss = 0.03190775
# Iteration 34, loss = 0.03123365
# Iteration 35, loss = 0.03232494
# Iteration 36, loss = 0.03211427
# Iteration 37, loss = 0.03178256
# Iteration 38, loss = 0.03041050
# Iteration 39, loss = 0.03114507
# Iteration 40, loss = 0.03112034
# Iteration 41, loss = 0.03019290
# Iteration 42, loss = 0.03085521
# Iteration 43, loss = 0.03066364
# Iteration 44, loss = 0.03060090
# Iteration 45, loss = 0.02978068
# Iteration 46, loss = 0.03030758
# Iteration 47, loss = 0.03028860
# Iteration 48, loss = 0.03017743
# Iteration 49, loss = 0.03018672
# Iteration 50, loss = 0.03111309
# Iteration 51, loss = 0.02965165
# Iteration 52, loss = 0.02955448
# Iteration 53, loss = 0.02980532
# Iteration 54, loss = 0.02925652
# Iteration 55, loss = 0.02935485
# Iteration 56, loss = 0.02905709
# Iteration 57, loss = 0.02945863
# Iteration 58, loss = 0.02816819
# Iteration 59, loss = 0.02872282
# Iteration 60, loss = 0.02907247
# Iteration 61, loss = 0.02826414
# Iteration 62, loss = 0.02897047
# Iteration 63, loss = 0.02833987
# Iteration 64, loss = 0.02810035
# Iteration 65, loss = 0.02749945
# Iteration 66, loss = 0.02815708
# Iteration 67, loss = 0.02863473
# Iteration 68, loss = 0.02820961
# Iteration 69, loss = 0.02763517
# Iteration 70, loss = 0.02789719
# Iteration 71, loss = 0.02716811
# Iteration 72, loss = 0.02732986
# Iteration 73, loss = 0.02847548
# Iteration 74, loss = 0.02691854
# Iteration 75, loss = 0.02738240
# Iteration 76, loss = 0.02775160
# Iteration 77, loss = 0.02719955
# Iteration 78, loss = 0.02765334
# Iteration 79, loss = 0.02760357
# Iteration 80, loss = 0.02662404
# Iteration 81, loss = 0.02723463
# Iteration 82, loss = 0.02667969
# Iteration 83, loss = 0.02673293
# Iteration 84, loss = 0.02663270
# Iteration 85, loss = 0.02641445
# Iteration 86, loss = 0.02665731
# Iteration 87, loss = 0.02616585
# Iteration 88, loss = 0.02632890
# Iteration 89, loss = 0.02601872
# Iteration 90, loss = 0.02685237
# Iteration 91, loss = 0.02538731
# Iteration 92, loss = 0.02600288
# Iteration 93, loss = 0.02595723
# Iteration 94, loss = 0.02594777
# Iteration 95, loss = 0.02598566
# Iteration 96, loss = 0.02574607
# Iteration 97, loss = 0.02521827
# Iteration 98, loss = 0.02580579
# Iteration 99, loss = 0.02539655
# Iteration 100, loss = 0.02573412
# Iteration 101, loss = 0.02519730
# Iteration 102, loss = 0.02503265
# Iteration 103, loss = 0.02484576
# Iteration 104, loss = 0.02525689
# Iteration 105, loss = 0.02512069
# Iteration 106, loss = 0.02495535
# Iteration 107, loss = 0.02489294
# Iteration 108, loss = 0.02503665
# Iteration 109, loss = 0.02462292
# Iteration 110, loss = 0.02475572
# Iteration 111, loss = 0.02461141
# Iteration 112, loss = 0.02531421
# Iteration 113, loss = 0.02488379
# Iteration 114, loss = 0.02479699
# Iteration 115, loss = 0.02496121
# Iteration 116, loss = 0.02539838
# Iteration 117, loss = 0.02454791
# Iteration 118, loss = 0.02461297
# Iteration 119, loss = 0.02470530
# Iteration 120, loss = 0.02440446
# Iteration 121, loss = 0.02460787
# Iteration 122, loss = 0.02444348
# Iteration 123, loss = 0.02487742
# Iteration 124, loss = 0.02453829
# Iteration 125, loss = 0.02425282
# Iteration 126, loss = 0.02404456
# Iteration 127, loss = 0.02436919
# Iteration 128, loss = 0.02404068
# Iteration 129, loss = 0.02483006
# Iteration 130, loss = 0.02439278
# Iteration 131, loss = 0.02484169
# Iteration 132, loss = 0.02441202
# Iteration 133, loss = 0.02462535
# Iteration 134, loss = 0.02404804
# Iteration 135, loss = 0.02384526
# Iteration 136, loss = 0.02420010
# Iteration 137, loss = 0.02411784
# Iteration 138, loss = 0.02386136
# Iteration 139, loss = 0.02396466
# Iteration 140, loss = 0.02370800
# Iteration 141, loss = 0.02432543
# Iteration 142, loss = 0.02428079
# Iteration 143, loss = 0.02417287
# Iteration 144, loss = 0.02332681
# Iteration 145, loss = 0.02415946
# Iteration 146, loss = 0.02389619
# Iteration 147, loss = 0.02365200
# Iteration 148, loss = 0.02409420
# Iteration 149, loss = 0.02450101
# Iteration 150, loss = 0.02387549
# Iteration 151, loss = 0.02369328
# Iteration 152, loss = 0.02366564
# Iteration 153, loss = 0.02389347
# Iteration 154, loss = 0.02390380
# Iteration 155, loss = 0.02369234
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# (27590,)
# [[25052    58]
#  [  184  2296]]
# 25052 58 184 2296
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     25110
#          1.0       0.98      0.93      0.95      2480
#
#    micro avg       0.99      0.99      0.99     27590
#    macro avg       0.98      0.96      0.97     27590
# weighted avg       0.99      0.99      0.99     27590
#
# hamming loss:  0.008771293947082277
# log loss:  0.3029514412547793
# zero one loss:  0.008771293947082315
# mean absolute error:  0.008771293947082277
# mean squared error:  0.008771293947082277
# mean squared log error:  0.004214194612838156
# median absolute error:  0.0
# accuracy score:  0.9912287060529177
# precision score:  0.9753610875106202
# recall score:  0.9258064516129032
# F1 score:  0.9499379395945386
# auc_score:  0.9617483074472322
# precision_recall_curve:
#  (array([0.08988764, 0.97536109, 1.        ]), array([1.        , 0.92580645, 0.        ]), array([0., 1.]))
# [0.08988764 0.97536109 1.        ] [1.         0.92580645 0.        ] [0. 1.]
# roc curve:
#  (array([0.        , 0.00230984, 1.        ]), array([0.        , 0.92580645, 1.        ]), array([2., 1., 0.]))
# [0.         0.00230984 1.        ] [0.         0.92580645 1.        ] [2. 1. 0.]
# /Users/user/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# (27590,)
# [[24977   133]
#  [   57  2423]]
# 24977 133 57 2423
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00     25110
#          1.0       0.95      0.98      0.96      2480
#
#    micro avg       0.99      0.99      0.99     27590
#    macro avg       0.97      0.99      0.98     27590
# weighted avg       0.99      0.99      0.99     27590
#
# hamming loss:  0.006886553098948894
# log loss:  0.23785697214538862
# zero one loss:  0.006886553098948922
# mean absolute error:  0.006886553098948894
# mean squared error:  0.006886553098948894
# mean squared log error:  0.003308665191897726
# median absolute error:  0.0
# accuracy score:  0.9931134469010511
# precision score:  0.9479655712050078
# recall score:  0.9770161290322581
# F1 score:  0.9622716441620334
# auc_score:  0.9858597172441258
# precision_recall_curve:
#  (array([0.08988764, 0.94796557, 1.        ]), array([1.        , 0.97701613, 0.        ]), array([0., 1.]))
# [0.08988764 0.94796557 1.        ] [1.         0.97701613 0.        ] [0. 1.]
# roc curve:
#  (array([0.        , 0.00529669, 1.        ]), array([0.        , 0.97701613, 1.        ]), array([2., 1., 0.]))
# [0.         0.00529669 1.        ] [0.         0.97701613 1.        ] [2. 1. 0.]
# /Users/user/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# (27590,)
# [[25076    34]
#  [   77  2403]]
# 25076 34 77 2403
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     25110
#          1.0       0.99      0.97      0.98      2480
#
#    micro avg       1.00      1.00      1.00     27590
#    macro avg       0.99      0.98      0.99     27590
# weighted avg       1.00      1.00      1.00     27590
#
# hamming loss:  0.004023196810438565
# log loss:  0.138957280396801
# zero one loss:  0.004023196810438612
# mean absolute error:  0.004023196810438565
# mean squared error:  0.004023196810438565
# mean squared log error:  0.0019329570331613028
# median absolute error:  0.0
# accuracy score:  0.9959768031895614
# precision score:  0.9860484201887567
# recall score:  0.9689516129032258
# F1 score:  0.977425259304454
# auc_score:  0.9837987853444843
# precision_recall_curve:
#  (array([0.08988764, 0.98604842, 1.        ]), array([1.        , 0.96895161, 0.        ]), array([0., 1.]))
# [0.08988764 0.98604842 1.        ] [1.         0.96895161 0.        ] [0. 1.]
# roc curve:
#  (array([0.        , 0.00135404, 1.        ]), array([0.        , 0.96895161, 1.        ]), array([2., 1., 0.]))
# [0.         0.00135404 1.        ] [0.         0.96895161 1.        ] [2. 1. 0.]
# (27590,)
# [[25003   107]
#  [   86  2394]]
# 25003 107 86 2394
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     25110
#          1.0       0.96      0.97      0.96      2480
#
#    micro avg       0.99      0.99      0.99     27590
#    macro avg       0.98      0.98      0.98     27590
# weighted avg       0.99      0.99      0.99     27590
#
# hamming loss:  0.0069952881478796665
# log loss:  0.24161179416972883
# zero one loss:  0.006995288147879641
# mean absolute error:  0.0069952881478796665
# mean squared error:  0.0069952881478796665
# mean squared log error:  0.0033609072738750587
# median absolute error:  0.0
# accuracy score:  0.9930047118521204
# precision score:  0.9572171131547381
# recall score:  0.9653225806451613
# F1 score:  0.9612527604898616
# auc_score:  0.9805306650736758
# precision_recall_curve:
#  (array([0.08988764, 0.95721711, 1.        ]), array([1.        , 0.96532258, 0.        ]), array([0., 1.]))
# [0.08988764 0.95721711 1.        ] [1.         0.96532258 0.        ] [0. 1.]
# roc curve:
#  (array([0.        , 0.00426125, 1.        ]), array([0.        , 0.96532258, 1.        ]), array([2., 1., 0.]))
# [0.         0.00426125 1.        ] [0.         0.96532258 1.        ] [2. 1. 0.]
# (27590,)
# [[23195  1915]
#  [  202  2278]]
# 23195 1915 202 2278
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.92      0.96     25110
#          1.0       0.54      0.92      0.68      2480
#
#    micro avg       0.92      0.92      0.92     27590
#    macro avg       0.77      0.92      0.82     27590
# weighted avg       0.95      0.92      0.93     27590
#
# hamming loss:  0.07673069952881478
# log loss:  2.65023997307375
# zero one loss:  0.07673069952881484
# mean absolute error:  0.07673069952881478
# mean squared error:  0.07673069952881478
# mean squared log error:  0.03686549584867098
# median absolute error:  0.0
# accuracy score:  0.9232693004711852
# precision score:  0.5432864297638922
# recall score:  0.9185483870967742
# F1 score:  0.6827513861831261
# auc_score:  0.921141975308642
# precision_recall_curve:
#  (array([0.08988764, 0.54328643, 1.        ]), array([1.        , 0.91854839, 0.        ]), array([0., 1.]))
# [0.08988764 0.54328643 1.        ] [1.         0.91854839 0.        ] [0. 1.]
# roc curve:
#  (array([0.        , 0.07626444, 1.        ]), array([0.        , 0.91854839, 1.        ]), array([2., 1., 0.]))
# [0.         0.07626444 1.        ] [0.         0.91854839 1.        ] [2. 1. 0.]

# %%
print(type(DT), DT, type(SVC), SVC, type(RF), RF)
# Out:
# <class 'sklearn.tree.tree.DecisionTreeClassifier'> DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') <class 'sklearn.svm.classes.SVC'> SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False) <class 'sklearn.ensemble.forest.RandomForestClassifier'> RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
df = pd.DataFrame(data=d)
print("Original DataFrame")
print(df)
print('After add one row:')
df2 = {'col1': 10, 'col2': 11, 'col3': 12}
df = df.append(df2, ignore_index=True)
print(df)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# After add one row:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# 5    10    11    12

# %%
t_payload = pd.read_csv('data/payloads.csv',index_col='index')
t_x = create_features(pd.DataFrame(t_payload['payload'][:]))

# %%
d = {'payload': []}
df = pd.DataFrame(data=d)
print("Original DataFrame")
display(df)
def create_payload(df, txt_data):
    print('After add one row:')
    df2 = {'payload': txt_data}
    df = df.append(df2, ignore_index=True) # df 需要重新赋值给它本身
    display(df)
    return df
df = create_payload(df, '? or 1=1 --')
df = create_payload(df, 'zyx213416')
df = create_payload(df, '\' and 1=0) union all')
df = create_payload(df, '\' and 1 in (select var from temp)--')
df = create_payload(df, '" or isNULL(1/0) /*')
# Out:
# Original DataFrame
# Empty DataFrame
# Columns: [payload]
# Index: []
# After add one row:
#        payload
# 0  ? or 1=1 --
# After add one row:
#        payload
# 0  ? or 1=1 --
# 1    zyx213416
# After add one row:
#                 payload
# 0           ? or 1=1 --
# 1             zyx213416
# 2  ' and 1=0) union all
# After add one row:
#                                payload
# 0                          ? or 1=1 --
# 1                            zyx213416
# 2                 ' and 1=0) union all
# 3  ' and 1 in (select var from temp)--
# After add one row:
#                                payload
# 0                          ? or 1=1 --
# 1                            zyx213416
# 2                 ' and 1=0) union all
# 3  ' and 1 in (select var from temp)--
# 4                  " or isNULL(1/0) /*

# %%
df_x = create_features(df[:])
# Out:
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['length'] = [len(str(r)) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['non_printable_chars'] = [len([1 for c in str(r) if c not in string.printable]) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['punctuation'] = [ len([1 for c in str(r) if c in string.punctuation]) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['max-byte'] = [ max(bytearray(str(r), 'utf-8')) for r in payloads['payload'] ]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['min-byte'] = [ min(bytearray(str(r), 'utf-8')) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['mean-byte'] = [ sum(bytearray(str(r), 'utf-8'))/ len(bytearray(str(r), 'utf-8')) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['standard-deviation-byte'] = [ np.std(bytearray(str(r), 'utf-8')) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:281: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['distinct-byte'] = [ len(set(str(r))) for r in payloads['payload']]
# /Users/user/Downloads/git_projects/back_end_projects/Insight_Project/Detector/Web_Attack_Predictor.py:308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   payloads['sql-keywords'] = [ len([1 for keyword in sql_keywords['Keyword'] if str(keyword).lower() in str(row).lower()]) for row in payloads['payload']]

# %%
display(df_x.head())
# Out:
#    length  non_printable_chars  punctuation  max-byte  min-byte  mean-byte  \
# 0      11                    0            4       114        32  57.545455
# 1       9                    0            0       122        49  74.222222
# 2      20                    0            3       117        32  76.950000
# 3      35                    0            5       118        32  81.371429
# 4      19                    0            6       115        32  63.368421
#
#    standard-deviation-byte  distinct-byte  sql-keywords
# 0                27.805701              7             0
# 1                33.111857              8             0
# 2                33.748296             13             3
# 3                34.587434             21             2
# 4                29.494354             15             1

# %%
DT.predict(df_x.head())
# Out:
# array([1., 0., 1., 1., 1.])

# %%
SVC.predict(df_x.head())
# Out:
# array([1., 0., 1., 1., 1.])

# %%
RF.predict(df_x.head())
# Out:
# array([1., 0., 1., 1., 1.])

# %%
for i in range(1,6): 
    display(t_x.tail(i))
    print( DT.predict(t_x.tail(i)) )
# Out:
#         length  non_printable_chars  punctuation  max-byte  min-byte  \
# index
# 110359     109                    0           16       122        32
#
#         mean-byte  standard-deviation-byte  distinct-byte  sql-keywords
# index
# 110359  90.990826                24.773653             50             3
# [1.]
#         length  non_printable_chars  punctuation  max-byte  min-byte  \
# index
# 110358      16                    0            0        57        48
# 110359     109                    0           16       122        32
#
#         mean-byte  standard-deviation-byte  distinct-byte  sql-keywords
# index
# 110358  53.375000                 2.368412              8             0
# 110359  90.990826                24.773653             50             3
# [0. 1.]
#         length  non_printable_chars  punctuation  max-byte  min-byte  \
# index
# 110357       9                    0            0       115        97
# 110358      16                    0            0        57        48
# 110359     109                    0           16       122        32
#
#          mean-byte  standard-deviation-byte  distinct-byte  sql-keywords
# index
# 110357  105.000000                 6.463573              8             0
# 110358   53.375000                 2.368412              8             0
# 110359   90.990826                24.773653             50             3
# [0. 0. 1.]
#         length  non_printable_chars  punctuation  max-byte  min-byte  \
# index
# 110356       7                    0            1       121        45
# 110357       9                    0            0       115        97
# 110358      16                    0            0        57        48
# 110359     109                    0           16       122        32
#
#          mean-byte  standard-deviation-byte  distinct-byte  sql-keywords
# index
# 110356   91.285714                25.257046              7             0
# 110357  105.000000                 6.463573              8             0
# 110358   53.375000                 2.368412              8             0
# 110359   90.990826                24.773653             50             3
# [0. 0. 0. 1.]
#         length  non_printable_chars  punctuation  max-byte  min-byte  \
# index
# 110355      12                    0            0       115       100
# 110356       7                    0            1       121        45
# 110357       9                    0            0       115        97
# 110358      16                    0            0        57        48
# 110359     109                    0           16       122        32
#
#          mean-byte  standard-deviation-byte  distinct-byte  sql-keywords
# index
# 110355  107.666667                 6.209312              5             1
# 110356   91.285714                25.257046              7             0
# 110357  105.000000                 6.463573              8             0
# 110358   53.375000                 2.368412              8             0
# 110359   90.990826                24.773653             50             3
# [0. 0. 0. 0. 1.]
